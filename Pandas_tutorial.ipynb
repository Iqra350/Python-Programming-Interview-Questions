# %%
import numpy as np
import pandas as pd

# %%
data = {'list1': [1, 3, 5, 6],
        'list2': ['one', 'two', 'NaN','six'],
        'list3': ['apple', 'bananan', 'mangoes', 'oranges']}
print(data)
# Out:
# {'list1': [1, 3, 5, 6], 'list2': ['one', 'two', 'NaN', 'six'], 'list3': ['apple', 'bananan', 'mangoes', 'oranges']}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    list1 list2    list3
# 0      1   one    apple
# 1      3   two  bananan
# 2      5   NaN  mangoes
# 3      6   six  oranges

# %%
df.to_csv('data.csv', index=False)

# %%
df.describe()
# Out:
#           list1
# count  4.000000
# mean   3.750000
# std    2.217356
# min    1.000000
# 25%    2.500000
# 50%    4.000000
# 75%    5.250000
# max    6.000000

# %%
df.columns = list('abc')
df
# Out:
#    a    b        c
# 0  1  one    apple
# 1  3  two  bananan
# 2  5  NaN  mangoes
# 3  6  six  oranges

# %%
df.loc[0,'a'] = 0
df
# Out:
#    a    b        c
# 0  0  one    apple
# 1  3  two  bananan
# 2  5  NaN  mangoes
# 3  6  six  oranges

# %%
df.isna()
# Out:
#        a      b      c
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
df['a' ] = None

# %%
df.isnull()
# Out:
#       a      b      c
# 0  True  False  False
# 1  True  False  False
# 2  True  False  False
# 3  True  False  False
